# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %%
url_LondonHousePrices= "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# %%
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %%
properties.shape
# Out:
# (318, 49)

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
properties_t= properties.T

# %%
properties_t.head(5)
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
properties_t.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties_t= properties_t.reset_index()

# %%
properties_t.head(3)
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1          94900.51244          110128.0423          112329.4376  ...
# 2          53700.34831          52113.12157          52232.19868  ...
#
#                    308                  309                  310  \
# ...

# %%
properties_t.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            308,     309,     310,     311,     312,     313,     314,     315,
#            316,     317],
#       dtype='object', length=319)

# %%
properties_t.iloc[[0]]
# Out:
#         index    0                    1                    2  \
# 0  Unnamed: 0  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
#
#                    308                  309                  310  \
# 0  2020-08-01 00:00:00  2020-09-01 00:00:00  2020-10-01 00:00:00
#
#                    311                  312                  313  \
# 0  2020-11-01 00:00:00  2020-12-01 00:00:00  2021-01-01 00:00:00
#
#                    314                  315                  316  \
# 0  2021-02-01 00:00:00  2021-03-01 00:00:00  2021-04-01 00:00:00
#
#                    317
# 0  2021-05-01 00:00:00
#
# [1 rows x 319 columns]

# %%
properties_t.columns=properties_t.iloc[0]

# %%
properties_t.head(5)
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
properties_t= properties_t.drop(0)

# %%
properties_t.head()
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %%
properties_t = properties_t.rename(columns = {'Unnamed: 0':'London_Borough', pd.NaT: 'ID'})

# %%
properties_t.head(3)
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# 2         53700.34831         52113.12157         52232.19868  ...
# 3         90107.23471         91441.24768         92361.31512  ...
#
# 0 2020-08-01 00:00:00 2020-09-01 00:00:00 2020-10-01 00:00:00  \
# 1         827658.5167         798499.1646         836807.0518
# ...

# %%
c_properties = pd.melt(properties_t, id_vars= ['London_Borough', 'ID'])

# %%
c_properties = c_properties.rename(columns = {0: 'Month', 'value': 'Average_price'})

# %%
c_properties
# Out:
#            London_Borough         ID      Month Average_price
# 0          City of London  E09000001 1995-01-01   91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01    50460.2266
# 2                  Barnet  E09000003 1995-01-01   93284.51832
# 3                  Bexley  E09000004 1995-01-01   64958.09036
# 4                   Brent  E09000005 1995-01-01   71306.56698
# ...                   ...        ...        ...           ...
# 15211              LONDON  E12000007 2021-05-01   497947.9589
# 15212          SOUTH EAST  E12000008 2021-05-01   350015.5072
# 15213          SOUTH WEST  E12000009 2021-05-01   277602.6983
# 15214         Unnamed: 47        NaN 2021-05-01           NaN
# 15215             England  E92000001 2021-05-01   271433.8707
#
# [15216 rows x 4 columns]

# %%
c_properties.isnull().sum()
# Out:
# London_Borough      0
# ID                951
# Month               0
# Average_price     951
# dtype: int64

# %%
c_properties['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
### The 32 London Districts 

columnsf = [
        'Barking & Dagenham', 'Barnet', 'Bexley', 'Brent',
        'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
        'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster'
    ]



c_properties2=c_properties[c_properties['London_Borough'].isin(columnsf)]
c_properties2
# Out:
#            London_Borough         ID      Month Average_price
# 1      Barking & Dagenham  E09000002 1995-01-01    50460.2266
# 2                  Barnet  E09000003 1995-01-01   93284.51832
# 3                  Bexley  E09000004 1995-01-01   64958.09036
# 4                   Brent  E09000005 1995-01-01   71306.56698
# 5                 Bromley  E09000006 1995-01-01   81671.47692
# ...                   ...        ...        ...           ...
# 15196              Sutton  E09000029 2021-05-01   394980.6279
# 15197       Tower Hamlets  E09000030 2021-05-01   474143.6754
# 15198      Waltham Forest  E09000031 2021-05-01   487133.1115
# 15199          Wandsworth  E09000032 2021-05-01   625412.3388
# 15200         Westminster  E09000033 2021-05-01   974523.3852
#
# [10144 rows x 4 columns]

# %%
c_properties2['London_Borough'].unique()
# Out:
# array(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley',
#        'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster'],
#       dtype=object)

# %%
c_properties2.isnull().sum()
# Out:
# London_Borough    0
# ID                0
# Month             0
# Average_price     0
# dtype: int64

# %%
c_properties2.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price             object
# dtype: object

# %%
c_properties2['Average_price']= pd.to_numeric(c_properties2['Average_price'])
# Out:
# <ipython-input-28-37498147e7de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_properties2['Average_price']= pd.to_numeric(c_properties2['Average_price'])

# %%
c_properties2.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# dtype: object

# %%
c_properties2
# Out:
#            London_Borough         ID      Month  Average_price
# 1      Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2                  Barnet  E09000003 1995-01-01    93284.51832
# 3                  Bexley  E09000004 1995-01-01    64958.09036
# 4                   Brent  E09000005 1995-01-01    71306.56698
# 5                 Bromley  E09000006 1995-01-01    81671.47692
# ...                   ...        ...        ...            ...
# 15196              Sutton  E09000029 2021-05-01   394980.62790
# 15197       Tower Hamlets  E09000030 2021-05-01   474143.67540
# 15198      Waltham Forest  E09000031 2021-05-01   487133.11150
# 15199          Wandsworth  E09000032 2021-05-01   625412.33880
# 15200         Westminster  E09000033 2021-05-01   974523.38520
#
# [10144 rows x 4 columns]

# %%
c_properties2['Year'] = c_properties2['Month'].apply(lambda t: t.year)
# Out:
# <ipython-input-31-7e31ef62be0f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_properties2['Year'] = c_properties2['Month'].apply(lambda t: t.year)

# %%
c_properties2
# Out:
#            London_Borough         ID      Month  Average_price  Year
# 1      Barking & Dagenham  E09000002 1995-01-01    50460.22660  1995
# 2                  Barnet  E09000003 1995-01-01    93284.51832  1995
# 3                  Bexley  E09000004 1995-01-01    64958.09036  1995
# 4                   Brent  E09000005 1995-01-01    71306.56698  1995
# 5                 Bromley  E09000006 1995-01-01    81671.47692  1995
# ...                   ...        ...        ...            ...   ...
# 15196              Sutton  E09000029 2021-05-01   394980.62790  2021
# 15197       Tower Hamlets  E09000030 2021-05-01   474143.67540  2021
# 15198      Waltham Forest  E09000031 2021-05-01   487133.11150  2021
# 15199          Wandsworth  E09000032 2021-05-01   625412.33880  2021
# 15200         Westminster  E09000033 2021-05-01   974523.38520  2021
#
# [10144 rows x 5 columns]

# %%
DF=  c_properties2.groupby(by=['London_Borough', 'Year']).mean()

# %%
DF
# Out:
#                          Average_price
# London_Borough     Year
# Barking & Dagenham 1995   5.181797e+04
#                    1996   5.171819e+04
#                    1997   5.597426e+04
#                    1998   6.028582e+04
#                    1999   6.532093e+04
# ...                                ...
# Westminster        2017   1.064772e+06
#                    2018   1.020025e+06
#                    2019   9.559986e+05
#                    2020   9.604692e+05
#                    2021   9.652117e+05
#
# [864 rows x 1 columns]

# %%
DF.index
# Out:
# MultiIndex([('Barking & Dagenham', 1995),
#             ('Barking & Dagenham', 1996),
#             ('Barking & Dagenham', 1997),
#             ('Barking & Dagenham', 1998),
#             ('Barking & Dagenham', 1999),
#             ('Barking & Dagenham', 2000),
#             ('Barking & Dagenham', 2001),
#             ('Barking & Dagenham', 2002),
#             ('Barking & Dagenham', 2003),
#             ('Barking & Dagenham', 2004),
#             ...
#             (       'Westminster', 2012),
#             (       'Westminster', 2013),
#             (       'Westminster', 2014),
#             (       'Westminster', 2015),
#             (       'Westminster', 2016),
#             (       'Westminster', 2017),
#             (       'Westminster', 2018),
#             (       'Westminster', 2019),
#             (       'Westminster', 2020),
#             (       'Westminster', 2021)],
#            names=['London_Borough', 'Year'], length=864)

# %%
DFF= DF.reset_index()

# %%
DFF
# Out:
#          London_Borough  Year  Average_price
# 0    Barking & Dagenham  1995   5.181797e+04
# 1    Barking & Dagenham  1996   5.171819e+04
# 2    Barking & Dagenham  1997   5.597426e+04
# 3    Barking & Dagenham  1998   6.028582e+04
# 4    Barking & Dagenham  1999   6.532093e+04
# ..                  ...   ...            ...
# 859         Westminster  2017   1.064772e+06
# 860         Westminster  2018   1.020025e+06
# 861         Westminster  2019   9.559986e+05
# 862         Westminster  2020   9.604692e+05
# 863         Westminster  2021   9.652117e+05
#
# [864 rows x 3 columns]

# %%
DFF.columns
# Out:
# Index(['London_Borough', 'Year', 'Average_price'], dtype='object')

# %%
def create_price_ratio(i):
    start = float(i['Average_price'][i['Year']==1998])
    end = float(i['Average_price'][i['Year']==2018])
    ratio = [end/start]
    return ratio

# %%
Borough_price_ratio= {}
for b in DFF['London_Borough'].unique():
    borough = DFF[DFF['London_Borough'] == b]
    Borough_price_ratio[b] = create_price_ratio(borough)

# %%
print(Borough_price_ratio)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.0947846853338765], 'Camden': [4.935353408884261], 'Croydon': [4.201100280024767], 'Ealing': [4.311450902121834], 'Enfield': [4.26347158349581], 'Greenwich': [4.763036347329193], 'Hackney': [6.198285561008662], 'Hammersmith & Fulham': [4.137798101936229], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335308], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Islington': [4.844048012802298], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'Lambeth': [4.957751163514063], 'Lewisham': [5.449221041059685], 'Merton': [4.741273313294604], 'Newham': [5.305390437201879], 'Redbridge': [4.471182006097364], 'Richmond upon Thames': [4.005161895721457], 'Southwark': [5.516485302379376], 'Sutton': [4.118522608573157], 'Tower Hamlets': [4.62670104006
# ...

# %%
InterestedDataFrame= pd.DataFrame(Borough_price_ratio)

# %%
print(InterestedDataFrame)
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    Croydon    Ealing   Enfield  Greenwich  ...    Merton   Newham  Redbridge  \
# 0   4.2011  4.311451  4.263472   4.763036  ...  4.741273  5.30539   4.471182
#
#    Richmond upon Thames  Southwark    Sutton  Tower Hamlets  Waltham Forest  \
# 0              4.005162   5.516485  4.118523       4.626701        5.834756
#
#    Wandsworth  Westminster
# 0    4.757709     5.353565
#
# [1 rows x 32 columns]

# %%
InterestedDataFrame_t= InterestedDataFrame.T

# %%
InterestedDataFrame_t
# Out:
#                              0
# Barking & Dagenham    4.896619
# Barnet                4.358196
# Bexley                4.248977
# Brent                 4.894554
# Bromley               4.094785
# Camden                4.935353
# Croydon               4.201100
# Ealing                4.311451
# Enfield               4.263472
# Greenwich             4.763036
# Hackney               6.198286
# Hammersmith & Fulham  4.137798
# Haringey              5.134625
# Harrow                4.059196
# Havering              4.325230
# Hillingdon            4.200273
# Hounslow              3.976409
# Islington             4.844048
# Kensington & Chelsea  5.082465
# Kingston upon Thames  4.270550
# Lambeth               4.957751
# Lewisham              5.449221
# Merton                4.741273
# Newham                5.305390
# Redbridge             4.471182
# Richmond upon Thames  4.005162
# Southwark             5.516485
# Sutton                4.118523
# Tower Hamlets         4.626701
# ...

# %%
Final_District= InterestedDataFrame_t.reset_index()

# %%
Final_District
# Out:
#                    index         0
# 0     Barking & Dagenham  4.896619
# 1                 Barnet  4.358196
# 2                 Bexley  4.248977
# 3                  Brent  4.894554
# 4                Bromley  4.094785
# 5                 Camden  4.935353
# 6                Croydon  4.201100
# 7                 Ealing  4.311451
# 8                Enfield  4.263472
# 9              Greenwich  4.763036
# 10               Hackney  6.198286
# 11  Hammersmith & Fulham  4.137798
# 12              Haringey  5.134625
# 13                Harrow  4.059196
# 14              Havering  4.325230
# 15            Hillingdon  4.200273
# 16              Hounslow  3.976409
# 17             Islington  4.844048
# 18  Kensington & Chelsea  5.082465
# 19  Kingston upon Thames  4.270550
# 20               Lambeth  4.957751
# 21              Lewisham  5.449221
# 22                Merton  4.741273
# 23                Newham  5.305390
# 24             Redbridge  4.471182
# 25  Richmond upon Thames  4.005162
# ...

# %%
Final_District.rename(columns={'index':'Borough', 0:'2018'}, inplace=True)

# %%
Final_District
# Out:
#                  Borough      2018
# 0     Barking & Dagenham  4.896619
# 1                 Barnet  4.358196
# 2                 Bexley  4.248977
# 3                  Brent  4.894554
# 4                Bromley  4.094785
# 5                 Camden  4.935353
# 6                Croydon  4.201100
# 7                 Ealing  4.311451
# 8                Enfield  4.263472
# 9              Greenwich  4.763036
# 10               Hackney  6.198286
# 11  Hammersmith & Fulham  4.137798
# 12              Haringey  5.134625
# 13                Harrow  4.059196
# 14              Havering  4.325230
# 15            Hillingdon  4.200273
# 16              Hounslow  3.976409
# 17             Islington  4.844048
# 18  Kensington & Chelsea  5.082465
# 19  Kingston upon Thames  4.270550
# 20               Lambeth  4.957751
# 21              Lewisham  5.449221
# 22                Merton  4.741273
# 23                Newham  5.305390
# 24             Redbridge  4.471182
# 25  Richmond upon Thames  4.005162
# ...

# %%
greatest_average_increaseinprice= Final_District.sort_values(by='2018',ascending=False)

# %%
greatest_average_increaseinprice
# Out:
#                  Borough      2018
# 10               Hackney  6.198286
# 29        Waltham Forest  5.834756
# 26             Southwark  5.516485
# 21              Lewisham  5.449221
# 31           Westminster  5.353565
# 23                Newham  5.305390
# 12              Haringey  5.134625
# 18  Kensington & Chelsea  5.082465
# 20               Lambeth  4.957751
# 5                 Camden  4.935353
# 0     Barking & Dagenham  4.896619
# 3                  Brent  4.894554
# 17             Islington  4.844048
# 9              Greenwich  4.763036
# 30            Wandsworth  4.757709
# 22                Merton  4.741273
# 28         Tower Hamlets  4.626701
# 24             Redbridge  4.471182
# 1                 Barnet  4.358196
# 14              Havering  4.325230
# 7                 Ealing  4.311451
# 19  Kingston upon Thames  4.270550
# 8                Enfield  4.263472
# 2                 Bexley  4.248977
# 6                Croydon  4.201100
# 15            Hillingdon  4.200273
# ...

# %%
priceincreasebygraph= greatest_average_increaseinprice[['Borough','2018']].plot(kind='bar')

priceincreasebygraph.set_xticklabels(greatest_average_increaseinprice.Borough)

plt.title('Average increase in housing prices over two decades')
plt.xlabel('London Boroughs')
plt.ylabel('Average Price increase')
# Out:
# Text(0, 0.5, 'Average Price increase')

# %% [markdown]
# Conclusion:
#
# Thus, according to the data, the greatest increase in housing price is showen in Hackney district and comparatively the lowest is seen in the Hounslow borough.
#
# see the graph.
