# %% [markdown]
# The is the notebook for the DC properies

# %%
import numpy as np 
import pandas as pd

# %%
dc_residential= pd.read_csv('dc_esidential.csv', index_col='SSL')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 dc_residential= pd.read_csv('dc_esidential.csv', index_col='SSL')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dc_esidential.csv'

# %%
dc_condo= pd.read_csv('dc_condo.csv', index_col='SSL')

# %%
address_points= pd.read_csv('address_points.csv')
# Out:
# /var/folders/vs/h329g4pd3s5bxc9z4khp1vw00000gn/T/ipykernel_23153/2452612820.py:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   address_points= pd.read_csv('address_points.csv')

# %%
df = pd.concat([dc_residential,dc_condo], sort=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 167286 entries, 0133    0106 to 6208    2011
# Data columns (total 40 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   BATHRM             165599 non-null  float64
#  1   HF_BATHRM          165491 non-null  float64
#  2   HEAT               165593 non-null  float64
#  3   HEAT_D             165593 non-null  object
#  4   AC                 165595 non-null  object
#  5   NUM_UNITS          107036 non-null  float64
#  6   ROOMS              165507 non-null  float64
#  7   BEDRM              165582 non-null  float64
#  8   AYB                167263 non-null  float64
#  9   YR_RMDL            89739 non-null   float64
#  10  EYB                167286 non-null  int64
#  11  STORIES            106949 non-null  float64
#  12  SALEDATE           167286 non-null  object
#  13  PRICE              150075 non-null  float64
#  14  QUALIFIED          167285 non-null  object
#  15  SALE_NUM           167286 non-null  int64
#  16  GBA                108285 non-null  float64
#  17  BLDG_NUM           167286 non-null  int64
#  18  STYLE              107035 non-null  float64
#  19  STYLE_D            107035 non-null  object
#  20  STRUCT             107036 non-null  float64
#  21  STRUCT_D           107036 non-null  object
#  22  GRADE              107036 non-null  float64
#  23  GRADE_D            107036 non-null  object
#  24  CNDTN              107036 non-null  float64
#  25  CNDTN_D            107036 non-null  object
#  26  EXTWALL            107036 non-null  float64
#  27  EXTWALL_D          107036 non-null  object
#  28  ROOF               107036 non-null  float64
#  29  ROOF_D             107036 non-null  object
#  30  INTWALL            107036 non-null  float64
#  31  INTWALL_D          107036 non-null  object
#  32  KITCHENS           107035 non-null  float64
#  33  FIREPLACES         165413 non-null  float64
#  34  USECODE            167286 non-null  int64
#  35  LANDAREA           167286 non-null  int64
#  36  GIS_LAST_MOD_DTTM  167286 non-null  object
#  37  OBJECTID           167286 non-null  int64
#  38  CMPLX_NUM          59001 non-null   float64
#  39  LIVING_GBA         59001 non-null   float64
# dtypes: float64(22), int64(6), object(12)
# memory usage: 52.3+ MB

# %%
df.head()
# Out:
#               BATHRM  HF_BATHRM  HEAT         HEAT_D AC  NUM_UNITS  ROOMS  \
# SSL
# 0133    0106     3.0        1.0  13.0  Hot Water Rad  N        4.0   12.0
# 0133    0114     4.0        0.0  13.0  Hot Water Rad  N        4.0   12.0
# 0133    0116     4.0        1.0  13.0  Hot Water Rad  Y        2.0    8.0
# 0133    0117     3.0        0.0  13.0  Hot Water Rad  Y        3.0    6.0
# 0133    0123     3.0        0.0   7.0      Warm Cool  Y        2.0    8.0
#
#               BEDRM     AYB  YR_RMDL  ...  INTWALL  INTWALL_D KITCHENS  \
# SSL                                   ...
# 0133    0106    4.0  1914.0   1987.0  ...      6.0   Hardwood      4.0
# 0133    0114    4.0  1900.0   2012.0  ...      6.0   Hardwood      4.0
# 0133    0116    4.0  1910.0   2013.0  ...      6.0   Hardwood      2.0
# 0133    0117    3.0  1895.0   2007.0  ...      6.0   Hardwood      3.0
# 0133    0123    4.0  1900.0   2019.0  ...      6.0   Hardwood      2.0
#
#               FIREPLACES USECODE  LANDAREA       GIS_LAST_MOD_DTTM  OBJECTID  \
# SSL
# 0133    0106         0.0      24      2208  2022/07/26 05:17:19+00  71045285
# 0133    0114         4.0      24      1368  2022/07/26 05:17:19+00  71045286
# 0133    0116         2.0      24      1012  2022/07/26 05:17:19+00  71045287
# 0133    0117         0.0      24       880  2022/07/26 05:17:19+00  71045288
# 0133    0123         1.0      24       792  2022/07/26 05:17:19+00  71045289
#
#               CMPLX_NUM LIVING_GBA
# SSL
# 0133    0106        NaN        NaN
# 0133    0114        NaN        NaN
# 0133    0116        NaN        NaN
# 0133    0117        NaN        NaN
# 0133    0123        NaN        NaN
#
# [5 rows x 40 columns]

# %%
#Next, eliminate redundant dummy codes for categorical values.

#Identify all categorical variables
categories = [['CNDTN_D','CNDTN'],['HEAT_D','HEAT'],['STYLE_D','STYLE'],['STRUCT_D','STRUCT'],['GRADE_D','GRADE'],['ROOF_D','ROOF'],['EXTWALL_D','EXTWALL'],['INTWALL_D','INTWALL']]
cat_drop = []
for c in categories:
    df[c[1]] = df[c[0]].astype('category')
    cat_drop.append(c[0])

#eliminate redundant dummy variables
df.drop(cat_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#               BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# SSL
# 0133    0106     3.0        1.0  Hot Water Rad  N        4.0   12.0    4.0
# 0133    0114     4.0        0.0  Hot Water Rad  N        4.0   12.0    4.0
# 0133    0116     4.0        1.0  Hot Water Rad  Y        2.0    8.0    4.0
# 0133    0117     3.0        0.0  Hot Water Rad  Y        3.0    6.0    3.0
# 0133    0123     3.0        0.0      Warm Cool  Y        2.0    8.0    4.0
#
#                  AYB  YR_RMDL   EYB  ...        ROOF   INTWALL  KITCHENS  \
# SSL                                  ...
# 0133    0106  1914.0   1987.0  1967  ...  Metal- Sms  Hardwood       4.0
# 0133    0114  1900.0   2012.0  1974  ...    Built Up  Hardwood       4.0
# 0133    0116  1910.0   2013.0  1976  ...    Built Up  Hardwood       2.0
# 0133    0117  1895.0   2007.0  1976  ...    Built Up  Hardwood       3.0
# 0133    0123  1900.0   2019.0  1976  ...    Built Up  Hardwood       2.0
#
#              FIREPLACES  USECODE  LANDAREA       GIS_LAST_MOD_DTTM  OBJECTID  \
# SSL
# 0133    0106        0.0       24      2208  2022/07/26 05:17:19+00  71045285
# 0133    0114        4.0       24      1368  2022/07/26 05:17:19+00  71045286
# 0133    0116        2.0       24      1012  2022/07/26 05:17:19+00  71045287
# 0133    0117        0.0       24       880  2022/07/26 05:17:19+00  71045288
# 0133    0123        1.0       24       792  2022/07/26 05:17:19+00  71045289
#
#              CMPLX_NUM LIVING_GBA
# SSL
# 0133    0106       NaN        NaN
# 0133    0114       NaN        NaN
# 0133    0116       NaN        NaN
# 0133    0117       NaN        NaN
# 0133    0123       NaN        NaN
#
# [5 rows x 32 columns]

# %%
print(df.isnull().sum())
# Out:
# BATHRM                 1687
# HF_BATHRM              1795
# HEAT                   1693
# AC                     1691
# NUM_UNITS             60250
# ROOMS                  1779
# BEDRM                  1704
# AYB                      23
# YR_RMDL               77547
# EYB                       0
# STORIES               60337
# SALEDATE                  0
# PRICE                 17211
# QUALIFIED                 1
# SALE_NUM                  0
# GBA                   59001
# BLDG_NUM                  0
# STYLE                 60251
# STRUCT                60250
# GRADE                 60250
# CNDTN                 60250
# EXTWALL               60250
# ROOF                  60250
# INTWALL               60250
# KITCHENS              60251
# FIREPLACES             1873
# USECODE                   0
# LANDAREA                  0
# GIS_LAST_MOD_DTTM         0
# OBJECTID                  0
# CMPLX_NUM            108285
# LIVING_GBA           108285
# dtype: int64

# %%
#It seems like there a few dozen entries that are missing key descriptors. Let's remove these rows.
df.dropna(subset=['ROOMS','BEDRM','BATHRM','HF_BATHRM','FIREPLACES','EYB','QUALIFIED'], inplace=True)

print(df.isnull().sum())
# Out:
# BATHRM                    0
# HF_BATHRM                 0
# HEAT                      0
# AC                        0
# NUM_UNITS             58266
# ROOMS                     0
# BEDRM                     0
# AYB                      20
# YR_RMDL               75654
# EYB                       0
# STORIES               58340
# SALEDATE                  0
# PRICE                 17203
# QUALIFIED                 0
# SALE_NUM                  0
# GBA                   58266
# BLDG_NUM                  0
# STYLE                 58266
# STRUCT                58266
# GRADE                 58266
# CNDTN                 58266
# EXTWALL               58266
# ROOF                  58266
# INTWALL               58266
# KITCHENS              58267
# FIREPLACES                0
# USECODE                   0
# LANDAREA                  0
# GIS_LAST_MOD_DTTM         0
# OBJECTID                  0
# CMPLX_NUM            106956
# LIVING_GBA           106956
# dtype: int64

# %%
#change data types to integer where appropriate.

int_col = ['BATHRM','HF_BATHRM','ROOMS','BEDRM','EYB','SALE_NUM','BLDG_NUM','FIREPLACES','LANDAREA']
#con_col = ['BATHRM','HF_BATHRM','NUM_UNITS','ROOMS','BEDRM','EYB','STORIES','SALE_NUM','KITCHENS','FIREPLACES','LANDAREA']

for i in int_col:
    df[i] = df[i].astype('int64')

# %%
# checking the datetime range 
print(df["SALEDATE"].sort_values(ascending=True).head(5))
# Out:
# SSL
# 2663    2018    1900/01/01 00:00:00+00
# 5483    0802    1900/01/01 00:00:00+00
# 3811    0101    1900/01/01 00:00:00+00
# 2222    2118    1900/01/01 00:00:00+00
# 5484    0030    1900/01/01 00:00:00+00
# Name: SALEDATE, dtype: object

# %%
print(df["SALEDATE"].sort_values(ascending=False).head(5))
# Out:
# SSL
# 4473    2071    2022/07/20 00:00:00+00
# 1601    2411    2022/07/20 00:00:00+00
# 2106    2119    2022/07/20 00:00:00+00
# 1601    2036    2022/07/20 00:00:00+00
# 2528    2233    2022/07/20 00:00:00+00
# Name: SALEDATE, dtype: object

# %%
#change data type to datetime where appropriate:

df['SALEDATE'] = pd.to_datetime(df['SALEDATE'], dayfirst=False)

# %%
print(df['SALEDATE'].head(5))
# Out:
# SSL
# 0133    0106   2021-12-21 00:00:00+00:00
# 0133    0114   2019-05-08 00:00:00+00:00
# 0133    0116   2022-05-13 00:00:00+00:00
# 0133    0117   1900-01-01 00:00:00+00:00
# 0133    0123   2021-05-27 00:00:00+00:00
# Name: SALEDATE, dtype: datetime64[ns, UTC]

# %%
address_points.head()
# Out:
#            X          Y  SITE_ADDRESS_PK  ADDRESS_ID  ROADWAYSEGID  STATUS  \
# 0 -77.000353  38.892195            27746       27746       11690.0  ACTIVE
# 1 -76.999249  38.892652            50808       50808        3073.0  ACTIVE
# 2 -76.999769  38.892558            51065       51065        3073.0  ACTIVE
# 3 -76.999231  38.892546            51219       51219        3073.0  ACTIVE
# 4 -76.997461  38.892194             3171        3171        9646.0  ACTIVE
#
#             SSL    TYPE_ ENTRANCETYPE  ADDRNUM  ... WARD_2012 ANC_2002  \
# 0  0814    0018  ADDRESS     OFFICIAL    402.0  ...    Ward 6   ANC 6C
# 1  0838    0027  ADDRESS     OFFICIAL    219.0  ...    Ward 6   ANC 6C
# 2  0814    0818  ADDRESS     OFFICIAL    216.0  ...    Ward 6   ANC 6C
# 3  0838    0041  ADDRESS     OFFICIAL    215.0  ...    Ward 6   ANC 6C
# 4  0866    0013  ADDRESS     OFFICIAL    626.0  ...    Ward 6   ANC 6C
#
#   ANC_2012  SMD_2002  SMD_2012 OBJECTID_12 OBJECTID OBJECTID_1 ANC_2023  \
# 0   ANC 6C  SMD 6C07  SMD 6C03      832017   1087.0     1509.0   ANC 6C
# 1   ANC 6C  SMD 6C07  SMD 6C03      832018   3265.0     1509.0   ANC 6C
# 2   ANC 6C  SMD 6C07  SMD 6C03      832019   3266.0     1509.0   ANC 6C
# 3   ANC 6C  SMD 6C07  SMD 6C03      832020   3267.0     1509.0   ANC 6C
# 4   ANC 6C  SMD 6C07  SMD 6C03      832021      1.0     1510.0   ANC 6C
#
#    SMD_2023
# 0  SMD 6C02
# 1  SMD 6C03
# 2  SMD 6C02
# 3  SMD 6C03
# 4  SMD 6C03
#
# [5 rows x 62 columns]

# %%
address_points['SSL'].isnull().sum()
# Out:
# 361

# %%
address_required = address_points.drop_duplicates(['SSL'], keep='last').set_index("SSL")[["FULLADDRESS","CITY","STATE","ZIPCODE","NATIONALGRID","LATITUDE","LONGITUDE","ASSESSMENT_NBHD","ASSESSMENT_SUBNBHD","CENSUS_TRACT","CENSUS_BLOCK","WARD"]]

# %%
pre_working_dc_property_data= pd.merge(df,address_required,how="left",on="SSL")

# %%
pre_working_dc_property_data.head(5)
# Out:
#               BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# SSL
# 0133    0106       3          1  Hot Water Rad  N        4.0     12      4
# 0133    0114       4          0  Hot Water Rad  N        4.0     12      4
# 0133    0116       4          1  Hot Water Rad  Y        2.0      8      4
# 0133    0117       3          0  Hot Water Rad  Y        3.0      6      3
# 0133    0123       3          0      Warm Cool  Y        2.0      8      4
#
#                  AYB  YR_RMDL   EYB  ...  STATE  ZIPCODE        NATIONALGRID  \
# SSL                                  ...
# 0133    0106  1914.0   1987.0  1967  ...     DC  20009.0  18S UJ 22930 09206
# 0133    0114  1900.0   2012.0  1974  ...     DC  20009.0  18S UJ 22857 09205
# 0133    0116  1910.0   2013.0  1976  ...     DC  20009.0  18S UJ 22872 09208
# 0133    0117  1895.0   2007.0  1976  ...     DC  20009.0  18S UJ 22878 09208
# 0133    0123  1900.0   2019.0  1976  ...     DC  20009.0  18S UJ 22967 09164
#
#                LATITUDE  LONGITUDE  ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  \
# SSL
# 0133    0106  38.913912 -77.042316       Old City 2    040 D Old City 2
# 0133    0114  38.913884 -77.043162       Old City 2    040 D Old City 2
# 0133    0116  38.913919 -77.042982       Old City 2    040 D Old City 2
# 0133    0117  38.913919 -77.042923       Old City 2    040 D Old City 2
# 0133    0123  38.913535 -77.041884       Old City 2    040 D Old City 2
#
#              CENSUS_TRACT CENSUS_BLOCK    WARD
# SSL
# 0133    0106       4202.0  004202 1001  Ward 2
# 0133    0114       4202.0  004202 1001  Ward 2
# 0133    0116       4202.0  004202 1001  Ward 2
# 0133    0117       4202.0  004202 1001  Ward 2
# 0133    0123       4202.0  004202 1001  Ward 2
#
# [5 rows x 44 columns]

# %%
pre_working_dc_property_data.isnull().sum()
# Out:
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              58266
# ROOMS                      0
# BEDRM                      0
# AYB                       20
# YR_RMDL                75654
# EYB                        0
# STORIES                58340
# SALEDATE                   0
# PRICE                  17203
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    58266
# BLDG_NUM                   0
# STYLE                  58266
# STRUCT                 58266
# GRADE                  58266
# CNDTN                  58266
# EXTWALL                58266
# ROOF                   58266
# INTWALL                58266
# KITCHENS               58267
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# OBJECTID                   0
# CMPLX_NUM             106956
# LIVING_GBA            106956
# FULLADDRESS            58969
# CITY                   58962
# STATE                  58962
# ZIPCODE                58962
# NATIONALGRID           58962
# LATITUDE               58962
# LONGITUDE              58962
# ASSESSMENT_NBHD        58962
# ASSESSMENT_SUBNBHD     74554
# CENSUS_TRACT           59016
# CENSUS_BLOCK           58962
# WARD                   58962
# dtype: int64
